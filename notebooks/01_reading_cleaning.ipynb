# %%
import pandas as pd

# %%
# ms = Messstellen
# ws = Wasserstände

cols_ms = ['messstelle_id', 'name', 'e32', 'n32', 'turnus_wasserstand', 'messstellenart',
           'freigabe_wstd', 'freigabe_chemie', 'freigabe_lage']
cols_ws = ['messstelle_id', 'datum_messung', 'abstich_m', 'hinweis', 'wasserstd_m', 'flurabstd_m', 'mph_m', 'gok_m', 'wwj']

cols_ms_dtype = {
    1: 'object', # messstelle_id
    19: 'category', # turnus_wasserstand
    20: 'category', # freigabe_wstd
    21: 'category', # freigabe_chemie
    22: 'category', # freigabe_lage
    27: 'category' # messstellenart
}

cols_ws_dtype = {
    1: 'object', # messstelle_id
    2: 'int32', # messstelle_sl_nr
    4: 'float32', # abstich_m
    5: 'object', # hinweis
    6: 'float32', # wasserstd_m
    7: 'float32', # flurabstd_m
    8: 'float32', # mph_m
    9: 'float32', #gok_m
    10: 'int32' # wwj
    }

# %%
df_ms = pd.read_csv("../data/raw/grundwasserdaten-NRW/OpenHygrisC_gw-messstelle.csv", 
                    encoding="utf-8", sep=";", decimal=",", thousands='.', usecols=cols_ms, dtype=cols_ms_dtype)
df_ws = pd.read_csv("../data/raw/grundwasserdaten-NRW/OpenHygrisC_gw-wasserstand_2010-2019.csv", 
                    encoding="utf-8", parse_dates=['datum_messung'], sep=";", decimal=',', thousands='.',
                    usecols=cols_ws, dtype = cols_ws_dtype, na_values=[""])

# %%
df_ms.dtypes
# Out:
# messstelle_id           object
# name                    object
# e32                     object
# n32                     object
# turnus_wasserstand    category
# freigabe_wstd         category
# freigabe_chemie       category
# freigabe_lage         category
# messstellenart        category
# dtype: object

# %%
df_ms.head(10)
# Out:
#   messstelle_id                 name     e32      n32  turnus_wasserstand  \
# 0     086610363  STRAM3               3071XX  56990XX       Einzelmessung
# 1     030302419  Monh-Baumberg        353497  5665195  Messstelle inaktiv
# 2     070283916  LGD BN KOTTENF. 3    362354  5615873           monatlich
# 3     010445730  60BP010505           2911XX  56692XX     vierzehntäglich
# 4     010445791  60BP010701           2908XX  56657XX     vierzehntäglich
# 5     076981812  RSK Wahner H. WH18   3688XX  56333XX  Messstelle inaktiv
# 6     010446722  60GP012301           2920XX  56453XX           monatlich
# 7     100151115  WE 33    WEHE        4787XX  58085XX           monatlich
# 8     073917310  K WA 37              3646XX  56364XX        halbjährlich
# 9     100604511  849      MLK 102,8S  4956XX  57947XX  Messstelle inaktiv
#
#   freigabe_wstd freigabe_chemie freigabe_lage  \
# 0            ja            nein          nein
# 1            ja              ja            ja
# 2            ja              ja            ja
# 3            ja            nein          nein
# 4            ja            nein          nein
# 5            ja            nein          nein
# 6            ja            nein          nein
# 7            ja            nein          nein
# 8            ja            nein          nein
# 9            ja            nein          nein
#
#                      messstellenart
# 0  GW-Messstelle
# 1  GW-Messstelle
# 2  GW-Messstelle
# 3  GW-Messstelle
# 4  GW-Messstelle
# 5  GW-Messstelle
# 6  GW-Messstelle
# 7  GW-Messstelle
# 8  GW-Messstelle
# 9  GW-Messstelle

# %%
print('NaN-Werte Messstellen')
display(df_ms.isna().sum())
print('---------------------')
print('NaN-Werte Wasserstände')
display(df_ws.isna().sum())
# Out:
# NaN-Werte Messstellen
# messstelle_id         0
# name                  0
# e32                   0
# n32                   0
# turnus_wasserstand    0
# freigabe_wstd         0
# freigabe_chemie       0
# freigabe_lage         0
# messstellenart        0
# dtype: int64
# ---------------------
# NaN-Werte Wasserstände
# messstelle_id        0
# datum_messung        0
# abstich_m            0
# hinweis              0
# wasserstd_m          0
# flurabstd_m      33427
# mph_m                0
# gok_m            33424
# wwj                  0
# dtype: int64

# %%
# Wenn der Turnus der Wasserstandsmessung NaN ist,
# findet die Messstelle keine Beachtung
df_ms = df_ms.dropna(subset=['turnus_wasserstand'])

# Wenn der Wasserstand NaN-Werte hat, ist die GW-Messstelle trocken.
# Diese GW-Messstellen sollen nicht näher betrachtet werden.
df_ws = df_ws.dropna(subset=['wasserstd_m'])

# %%
print('NaN-Werte Messstellen')
display(df_ms.isna().sum())
print('---------------------')
print('NaN-Werte Wasserstände')
display(df_ws.isna().sum())
# Out:
# NaN-Werte Messstellen
# messstelle_id         0
# name                  0
# e32                   0
# n32                   0
# turnus_wasserstand    0
# freigabe_wstd         0
# freigabe_chemie       0
# freigabe_lage         0
# messstellenart        0
# dtype: int64
# ---------------------
# NaN-Werte Wasserstände
# messstelle_id        0
# datum_messung        0
# abstich_m            0
# hinweis              0
# wasserstd_m          0
# flurabstd_m      33427
# mph_m                0
# gok_m            33424
# wwj                  0
# dtype: int64

# %%
# Correction of missing coordinates. Replace XX with the mean value of 50. For plotting in GIS.
mask = df_ms['freigabe_lage'] == 'nein'

df_ms.loc[mask, 'e32'] = df_ms.loc[mask, 'e32'].str.replace("XX", "50")
df_ms.loc[mask, 'n32'] = df_ms.loc[mask, 'n32'].str.replace("XX", "50")

# %%
df_ms.head(10)
# Out:
#   messstelle_id                 name     e32      n32  turnus_wasserstand  \
# 0     086610363  STRAM3               307150  5699050       Einzelmessung
# 1     030302419  Monh-Baumberg        353497  5665195  Messstelle inaktiv
# 2     070283916  LGD BN KOTTENF. 3    362354  5615873           monatlich
# 3     010445730  60BP010505           291150  5669250     vierzehntäglich
# 4     010445791  60BP010701           290850  5665750     vierzehntäglich
# 5     076981812  RSK Wahner H. WH18   368850  5633350  Messstelle inaktiv
# 6     010446722  60GP012301           292050  5645350           monatlich
# 7     100151115  WE 33    WEHE        478750  5808550           monatlich
# 8     073917310  K WA 37              364650  5636450        halbjährlich
# 9     100604511  849      MLK 102,8S  495650  5794750  Messstelle inaktiv
#
#   freigabe_wstd freigabe_chemie freigabe_lage  \
# 0            ja            nein          nein
# 1            ja              ja            ja
# 2            ja              ja            ja
# 3            ja            nein          nein
# 4            ja            nein          nein
# 5            ja            nein          nein
# 6            ja            nein          nein
# 7            ja            nein          nein
# 8            ja            nein          nein
# 9            ja            nein          nein
#
#                      messstellenart
# 0  GW-Messstelle
# 1  GW-Messstelle
# 2  GW-Messstelle
# 3  GW-Messstelle
# 4  GW-Messstelle
# 5  GW-Messstelle
# 6  GW-Messstelle
# 7  GW-Messstelle
# 8  GW-Messstelle
# 9  GW-Messstelle

# %%
df_ws.head(10)
# Out:
#    messstelle_id datum_messung  abstich_m hinweis  wasserstd_m  flurabstd_m  \
# 1      218086015    2019-10-13   0.510000       -    74.760002    -0.440000
# 2      010305970    2019-08-12   3.440000       -    41.070000     2.710000
# 3      219610927    2012-05-22  22.840000       -    75.440002    22.950001
# 4      219610927    2012-06-27  22.780001       -    75.500000    22.889999
# 5      219610927    2012-07-26  22.799999       -    75.480003    22.910000
# 6      219610927    2012-08-21  22.830000       -    75.449997    22.940001
# 7      219610927    2012-09-25  22.799999       -    75.480003    22.910000
# 8      219610927    2012-10-24  22.809999       -    75.470001    22.920000
# 9      219610927    2012-11-21  22.840000       -    75.440002    22.950001
# 10     219610927    2013-01-03  22.850000       -    75.430000    22.959999
#
#         mph_m      gok_m   wwj
# 1   75.269997  74.320000  2019
# 2   44.509998  43.779999  2019
# 3   98.279999  98.389999  2012
# 4   98.279999  98.389999  2012
# 5   98.279999  98.389999  2012
# 6   98.279999  98.389999  2012
# 7   98.279999  98.389999  2012
# 8   98.279999  98.389999  2012
# 9   98.279999  98.389999  2013
# 10  98.279999  98.389999  2013

# %%
df_ms_cross = pd.crosstab(index=df_ms.loc[:, 'messstellenart'], columns=df_ms.loc[:, 'turnus_wasserstand'])

df_ms_cross
# Out:
# turnus_wasserstand                   -  2-monatlich  Einzelmessung  \
# messstellenart
# Bergbauschacht                       0            0              0
# Bodenaufschlussbohrungen             0            0              2
# GW-Messstelle                     2160          431           2402
# Grundwasserblänke                    0            0              0
# Horizontalfilterbrunnen              0            0              8
# Mehrfachmessstelle                   0            0              2
# Pegel                                0            9             13
# Rohmischwassermessstelle             0            0              0
# Sammelmessstelle                     0            0              0
# Sammelschacht                        0            0              3
# Schachtbrunnen                      26            2             61
# Sickerleitung                        0            0              0
# Sickerstollen                        0            0              3
# Sonstige Messstellenarten            0            0             27
# Talsperre, Flusswassermesstelle      0            0              2
# Vertikalfilterbrunnen               22           17           1133
# gefasste Quelle                      0            0             18
# ungefasste Quelle                    0            0              5
#
# turnus_wasserstand                Messstelle besteht nicht mehr  \
# messstellenart
# Bergbauschacht                                                0
# Bodenaufschlussbohrungen                                    686
# GW-Messstelle                                              7431
# Grundwasserblänke                                             1
# Horizontalfilterbrunnen                                       1
# Mehrfachmessstelle                                            1
# Pegel                                                        45
# Rohmischwassermessstelle                                      1
# Sammelmessstelle                                              0
# Sammelschacht                                                 0
# Schachtbrunnen                                              399
# Sickerleitung                                                 0
# Sickerstollen                                                 0
# Sonstige Messstellenarten                                     3
# Talsperre, Flusswassermesstelle                               0
# Vertikalfilterbrunnen                                       365
# gefasste Quelle                                               1
# ungefasste Quelle                                             0
#
# turnus_wasserstand                Messstelle inaktiv  halbjährlich  jährlich  \
# messstellenart
# Bergbauschacht                                     0             7         0
# Bodenaufschlussbohrungen                           2             0         0
# GW-Messstelle                                  18204          3660       464
# Grundwasserblänke                                 59             6         0
# Horizontalfilterbrunnen                           28             6        11
# Mehrfachmessstelle                                 0             2         2
# Pegel                                            174            19         0
# Rohmischwassermessstelle                          40             0         0
# Sammelmessstelle                                  34             1         0
# Sammelschacht                                     28             0         0
# Schachtbrunnen                                  5691           251         2
# Sickerleitung                                     10             0         0
# Sickerstollen                                     12             1         0
# Sonstige Messstellenarten                          4             0         0
# Talsperre, Flusswassermesstelle                   14             0         0
# Vertikalfilterbrunnen                           2823           413        67
# gefasste Quelle                                  121             1         4
# ungefasste Quelle                                 58             2         0
#
# turnus_wasserstand                monatlich  täglich  vierteljährlich  \
# messstellenart
# Bergbauschacht                           25       11                7
# Bodenaufschlussbohrungen                  0        2                0
# GW-Messstelle                         22497     1692              714
# Grundwasserblänke                        19        1                1
# Horizontalfilterbrunnen                  11        1                0
# Mehrfachmessstelle                       12        1                0
# Pegel                                   336       21               14
# Rohmischwassermessstelle                  1        0                0
# Sammelmessstelle                          1        0                0
# Sammelschacht                             8        0                0
# Schachtbrunnen                          278        9               24
# Sickerleitung                             0        0                0
# Sickerstollen                             2        0                2
# Sonstige Messstellenarten                12        0                0
# Talsperre, Flusswassermesstelle           0        0                0
# Vertikalfilterbrunnen                  1138       50               11
# gefasste Quelle                           0        0                0
# ungefasste Quelle                         0        0                4
#
# turnus_wasserstand                vierzehntäglich  \
# messstellenart
# Bergbauschacht                                  0
# Bodenaufschlussbohrungen                        0
# GW-Messstelle                                 864
# Grundwasserblänke                               0
# Horizontalfilterbrunnen                         1
# Mehrfachmessstelle                              0
# Pegel                                           7
# Rohmischwassermessstelle                        0
# Sammelmessstelle                                0
# Sammelschacht                                   0
# Schachtbrunnen                                 21
# Sickerleitung                                   0
# Sickerstollen                                   0
# Sonstige Messstellenarten                       0
# Talsperre, Flusswassermesstelle                 0
# Vertikalfilterbrunnen                          53
# gefasste Quelle                                 2
# ungefasste Quelle                               2
#
# turnus_wasserstand                vierzehntäglich (gerade Wochen)  \
# messstellenart
# Bergbauschacht                                                  0
# Bodenaufschlussbohrungen                                        0
# GW-Messstelle                                                 180
# Grundwasserblänke                                               0
# Horizontalfilterbrunnen                                         0
# Mehrfachmessstelle                                              0
# Pegel                                                           0
# Rohmischwassermessstelle                                        0
# Sammelmessstelle                                                0
# Sammelschacht                                                   0
# Schachtbrunnen                                                  2
# Sickerleitung                                                   0
# Sickerstollen                                                   0
# Sonstige Messstellenarten                                       0
# Talsperre, Flusswassermesstelle                                 0
# Vertikalfilterbrunnen                                          15
# gefasste Quelle                                                 0
# ungefasste Quelle                                               0
#
# turnus_wasserstand                vierzehntäglich (ung. Wochen)  wöchentlich
# messstellenart
# Bergbauschacht                                                0            0
# Bodenaufschlussbohrungen                                      0            0
# GW-Messstelle                                                61          990
# Grundwasserblänke                                             0            3
# Horizontalfilterbrunnen                                       0            4
# Mehrfachmessstelle                                            0            1
# Pegel                                                         0           51
# Rohmischwassermessstelle                                      0            0
# Sammelmessstelle                                              0            0
# Sammelschacht                                                 0            3
# Schachtbrunnen                                                2           14
# Sickerleitung                                                 0            0
# Sickerstollen                                                 3            0
# Sonstige Messstellenarten                                     0            0
# Talsperre, Flusswassermesstelle                               0            0
# Vertikalfilterbrunnen                                         4          135
# gefasste Quelle                                               2            0
# ungefasste Quelle                                             0            0

# %%
# Boolean Mask with all conditions
df_ms_mask = (
    (df_ms.loc[:, 'messstellenart'].str.strip() == 'GW-Messstelle') & 
    ((df_ms['turnus_wasserstand'] == 'monatlich') | (df_ms['turnus_wasserstand'] == 'täglich') |
     (df_ms['turnus_wasserstand'] == 'vierzehntäglich') | (df_ms['turnus_wasserstand'] == 'wöchentlich')) & 
    (df_ms.loc[:, 'freigabe_wstd'] == 'ja')
)

# %%
df_ms_ws_m = pd.merge(
    df_ms[df_ms_mask],
    df_ws,
    on="messstelle_id",
    how="inner"
)

df_ms_ws_m.head(5)
# Out:
#   messstelle_id                 name     e32      n32 turnus_wasserstand  \
# 0     070283916  LGD BN KOTTENF. 3    362354  5615873          monatlich
# 1     070283916  LGD BN KOTTENF. 3    362354  5615873          monatlich
# 2     070283916  LGD BN KOTTENF. 3    362354  5615873          monatlich
# 3     070283916  LGD BN KOTTENF. 3    362354  5615873          monatlich
# 4     070283916  LGD BN KOTTENF. 3    362354  5615873          monatlich
#
#   freigabe_wstd freigabe_chemie freigabe_lage  \
# 0            ja              ja            ja
# 1            ja              ja            ja
# 2            ja              ja            ja
# 3            ja              ja            ja
# 4            ja              ja            ja
#
#                      messstellenart datum_messung  abstich_m hinweis  \
# 0  GW-Messstelle                       2016-03-21       6.17       -
# 1  GW-Messstelle                       2016-04-21       5.95       -
# 2  GW-Messstelle                       2016-05-24       5.88       -
# 3  GW-Messstelle                       2016-06-24       5.82       -
# 4  GW-Messstelle                       2016-07-25       5.84       -
#
#    wasserstd_m  flurabstd_m       mph_m       gok_m   wwj
# 0   158.779999         5.56  164.949997  164.339996  2016
# 1   159.000000         5.34  164.949997  164.339996  2016
# 2   159.070007         5.27  164.949997  164.339996  2016
# 3   159.130005         5.21  164.949997  164.339996  2016
# 4   159.110001         5.23  164.949997  164.339996  2016

# %%
print(f"Anzahl der relevanten Messstellen in der messstellen.csv: {len(df_ms[df_ms_mask].loc[:, 'messstelle_id'].unique())}")
print(f'Anzahl aller Wasserstände in der wasserstand.csv: {len(df_ws.loc[:, 'messstelle_id'].unique())}')
print('---------------------------------------------------------')
print(f'Anzahl der resultierenden Messstellen aus merge: {len(df_ms_ws_m.loc[:, 'messstelle_id'].unique())}')
# Out:
# Anzahl der relevanten Messstellen in der messstellen.csv: 12384
# Anzahl aller Wasserstände in der wasserstand.csv: 18494
# ---------------------------------------------------------
# Anzahl der resultierenden Messstellen aus merge: 11348

# %%
# Selection of measuring points where sufficient groundwater levels are present
df_selected_ms = (
    df_ms_ws_m
    .drop_duplicates(subset="messstelle_id")
    .drop(columns=["datum_messung", "abstich_m", "hinweis", "wasserstd_m", "flurabstd_m", "mph_m", "gok_m", "wwj"])
    .reset_index(drop=True)
    )

# %%
df_ms_ws_m.dtypes
# Out:
# messstelle_id                 object
# name                          object
# e32                           object
# n32                           object
# turnus_wasserstand          category
# freigabe_wstd               category
# freigabe_chemie             category
# freigabe_lage               category
# messstellenart              category
# datum_messung         datetime64[ns]
# abstich_m                    float32
# hinweis                       object
# wasserstd_m                  float32
# flurabstd_m                  float32
# mph_m                        float32
# gok_m                        float32
# wwj                            int32
# dtype: object

# %%
# Export DataFrame to CSV and Pickle
df_ms.to_pickle("../data/processed/grundwasserdaten-NRW/GW-Messstellen.pkl")
df_ms.to_csv("../data/processed/grundwasserdaten-NRW/GW-Messstellen.csv")
df_ws.to_pickle("../data/processed/grundwasserdaten-NRW/GW-Wasserstaende.pkl")
df_ms_ws_m.to_pickle("../data/processed/grundwasserdaten-NRW/GW-MessWasserstellenMerge.pkl")
df_selected_ms.to_csv("../data/processed/grundwasserdaten-NRW/GW-MessstellenSelected.csv")
